# %%
# reading data
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# '/work/New_drive/Cultural_data_science/cult_data/data'

# %%
df = pd.read_csv('/work/New_drive/Cultural_data_science/cult_data/data/mp_data1.csv')

# %%
# checking out data
df[500:800]
# Out:
#        ID          sender    sender_type    sender_id    ended_on  duration  \
# 500  4549  Trial Sequence  flow.Sequence     12_1_0_6  completion    1444.3
# 501  4549        fixation  canvas.Screen   12_1_0_7_0     timeout     541.9
# 502  4549           mask1  canvas.Screen   12_1_0_7_1     timeout      50.9
# 503  4549           prime  canvas.Screen   12_1_0_7_2     timeout      42.4
# 504  4549           mask2  canvas.Screen   12_1_0_7_3     timeout      43.3
# ..    ...             ...            ...          ...         ...       ...
# 795  4549        fixation  canvas.Screen  12_1_0_56_0     timeout     543.2
# 796  4549           mask1  canvas.Screen  12_1_0_56_1     timeout      49.2
# 797  4549           prime  canvas.Screen  12_1_0_56_2     timeout      43.4
# 798  4549           mask2  canvas.Screen  12_1_0_56_3     timeout      38.4
# 799  4549          target  canvas.Screen  12_1_0_56_4    response     670.4
#
# ...

# %%
# filtering data frame
df = df[df['sender'] == 'target'] # a great and concise way to filter; and quite similar to R syntax
df
# Out:
#          ID  sender    sender_type    sender_id  ended_on  duration  time_run  \
# 14     4549  target  canvas.Screen       10_0_4  response     840.0   60076.1
# 20     4549  target  canvas.Screen       10_1_4  response     643.3   61641.0
# 26     4549  target  canvas.Screen       10_2_4  response     782.7   62991.0
# 32     4549  target  canvas.Screen       10_3_4  response     839.9   64501.5
# 41     4549  target  canvas.Screen   12_0_0_0_5  response     742.4   67989.8
# ...     ...     ...            ...          ...       ...       ...       ...
# 18917  4526  target  canvas.Screen  12_1_0_55_5  response     608.9  198693.2
# 18924  4526  target  canvas.Screen  12_1_0_56_5  response     496.9  200054.2
# 18931  4526  target  canvas.Screen  12_1_0_57_5  response     525.6  201283.3
# 18938  4526  target  canvas.Screen  12_1_0_58_5  response     503.0  202554.5
# 18945  4526  target  canvas.Screen  12_1_0_59_5  response     677.7  203789.9
#
# ...

# %%
set(df['sender']) # similar to unique() in R
# Out:
# {'target'}

# %%
# there is a problem with the correct_response column. Let's fix it.
df['response_action'] = df['response_action'].str.replace('keypress(', '')
df['response_action'] = df['response_action'].str.replace(')', '')
df
# Out:
#          ID  sender    sender_type    sender_id  ended_on  duration  time_run  \
# 14     4549  target  canvas.Screen       10_0_4  response     840.0   60076.1
# 20     4549  target  canvas.Screen       10_1_4  response     643.3   61641.0
# 26     4549  target  canvas.Screen       10_2_4  response     782.7   62991.0
# 32     4549  target  canvas.Screen       10_3_4  response     839.9   64501.5
# 41     4549  target  canvas.Screen   12_0_0_0_5  response     742.4   67989.8
# ...     ...     ...            ...          ...       ...       ...       ...
# 18917  4526  target  canvas.Screen  12_1_0_55_5  response     608.9  198693.2
# 18924  4526  target  canvas.Screen  12_1_0_56_5  response     496.9  200054.2
# 18931  4526  target  canvas.Screen  12_1_0_57_5  response     525.6  201283.3
# 18938  4526  target  canvas.Screen  12_1_0_58_5  response     503.0  202554.5
# 18945  4526  target  canvas.Screen  12_1_0_59_5  response     677.7  203789.9
#
# ...

# %%
df['correct'] = df['response_action'] == df['correct_response']

# %%
set(df['correct'])
# Out:
# {False, True}

# %%
list(df) # this gives all the columns
# Out:
# ['ID',
#  'sender',
#  'sender_type',
#  'sender_id',
#  'ended_on',
#  'duration',
#  'time_run',
#  'time_render',
#  'time_show',
#  'time_end',
#  'time_commit',
#  'timestamp',
#  'time_switch',
#  'response',
#  'response_action',
#  'prime',
#  'target',
#  'condition',
#  'soa_condition',
#  'congruence',
#  'correct_response',
#  'correctResponse',
#  'correct']

# %%
data = df.loc[:, ['ID', 'duration', 'condition', 'soa_condition', 'congruence', 'correct']]
data = data[data['condition'] != 'practice']
data = data[data['correct'] != False]

# %%
data
# Out:
#          ID  duration        condition soa_condition   congruence  correct
# 41     4549     742.4  Inc_Synth_Synth          long  incongruent     True
# 55     4549     725.9          Con_Nat          long    congruent     True
# 62     4549     796.7          Con_Nat          long    congruent     True
# 69     4549     815.1  Inc_Synth_Synth          long  incongruent     True
# 76     4549     673.5  Inc_Synth_Synth          long  incongruent     True
# ...     ...       ...              ...           ...          ...      ...
# 18903  4526     556.6    Inc_Synth_Nat          long  incongruent     True
# 18917  4526     608.9    Inc_Nat_Synth          long  incongruent     True
# 18924  4526     496.9    Inc_Nat_Synth          long  incongruent     True
# 18938  4526     503.0          Con_Nat          long    congruent     True
# 18945  4526     677.7  Inc_Synth_Synth          long  incongruent     True
#
# [2320 rows x 6 columns]

# %%
# visualisation time

# %%
# %pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
sns.pointplot(data=data, x = 'soa_condition', y='duration', hue='congruence', order = ['short','long'])
plt.ylabel('RT ms')
plt.xlabel('SOA Condition')
plt.title('Plot')

sns.despine()

# %%
print(min(list(data['duration'])))
print(max(list(data['duration'])))
# Out:
# 343.4000001907407
# 1981.0

# %%
sns.histplot(data['duration'])
sns.despine()
